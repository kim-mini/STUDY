# %% [markdown]
# ## 1. Numpy import 하기

# %%
import numpy

# %%
numpy
# Out:
# <module 'numpy' from '/home/ubuntu/anaconda3/envs/opencv4/lib/python3.7/site-packages/numpy/__init__.py'>

# %% [markdown]
# ### 1-1. 별칭 (alias) 지정하기 (항상 해주세요!)

# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from '/home/ubuntu/anaconda3/envs/opencv4/lib/python3.7/site-packages/numpy/__init__.py'>

# %% [markdown]
# ## 2. ndarray 생성하기

# %%
arr = np.array([1, 2, 3, 4], dtype=int)

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 2-1. list로 부터 생성하기

# %%
mylist1 = [1, 2, 3, 4]

# %%
mylist2 = [[1, 2, 3, 4], 
           [5, 6, 7, 8]]

# %%
arr1 = np.array(mylist1)

# %%
arr2 = np.array(mylist2)

# %%
print(arr1)
# Out:
# [1 2 3 4]

# %%
print(arr2)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
type(arr2)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 2-2. shape확인하기

# %%
arr1.shape
# Out:
# (4,)

# %%
arr2.shape
# Out:
# (2, 4)

# %% [markdown]
# ## 3. array에서의 data 타입

# %% [markdown]
# array에서는 list와는 다르게 1개의 **단일 데이터 타입**만 허용 됩니다.

# %% [markdown]
# ### 3-1. list에서의 data 타입

# %%
mylist = [1, 3.14, 'hello', '1234']

# %%
mylist
# Out:
# [1, 3.14, 'hello', '1234']

# %%
mylist[1]
# Out:
# 3.14

# %%
mylist[2]
# Out:
# 'hello'

# %% [markdown]
# ### 3-2. array에서의 data 타입 (case를 통한 연구)

# %% [markdown]
# ### case 1. int와 float 타입이 혼재된 경우

# %%
arr = np.array([1, 2, 3, 3.14])

# %%
arr
# Out:
# array([1.  , 2.  , 3.  , 3.14])

# %% [markdown]
# ### case 2. int와 float 타입이 혼재되었으나, dtype을 지정한 경우

# %%
arr = np.array([1, 2, 3, 3.14], dtype=int)

# %%
arr
# Out:
# array([1, 2, 3, 3])

# %% [markdown]
# ### case 3. int와 str 타입이 혼재된 경우

# %%
arr = np.array([1, 3.14, '테디', '1234'])

# %%
arr
# Out:
# array(['1', '3.14', '테디', '1234'], dtype='<U32')

# %%
arr[0] + arr[1]
# Out:
# '13.14'

# %% [markdown]
# ### case 4. int와 str 타입이 혼재되어 있고 int로 dtype을 지정한 경우

# %%
arr = np.array([1, 3.14, '1234'], dtype=int)

# %%
    arr
# Out:
# array([   1,    3, 1234])
