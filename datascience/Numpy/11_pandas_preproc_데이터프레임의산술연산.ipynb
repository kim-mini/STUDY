# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 예제 DataFrame 생성

# %%
df = pd.DataFrame({'통계': [60, 70, 80, 85, 75], '미술': [50, 55, 80, 100, 95], '체육': [70, 65, 50, 95, 100] })

# %%
df
# Out:
#    통계   미술   체육
# 0  60   50   70
# 1  70   55   65
# 2  80   80   50
# 3  85  100   95
# 4  75   95  100

# %% [markdown]
# ## 1. Column 과 Column 간 연산 (+, -, *, /, %)

# %%
type(df['통계'])
# Out:
# pandas.core.series.Series

# %%
df['통계'] + df['미술'] + df['체육']
# Out:
# 0    180
# 1    190
# 2    210
# 3    280
# 4    270
# dtype: int64

# %%
df['통계'] - df['미술']
# Out:
# 0    10
# 1    15
# 2     0
# 3   -15
# 4   -20
# dtype: int64

# %%
df['통계'] * df['미술']
# Out:
# 0    3000
# 1    3850
# 2    6400
# 3    8500
# 4    7125
# dtype: int64

# %%
df['통계'] / df['미술']
# Out:
# 0    1.200000
# 1    1.272727
# 2    1.000000
# 3    0.850000
# 4    0.789474
# dtype: float64

# %%
df['통계'] % df['미술']
# Out:
# 0    10
# 1    15
# 2     0
# 3    85
# 4    75
# dtype: int64

# %% [markdown]
# ## 2. Column 과 숫자 간 연산 (+, -, *, /, %)

# %%
df['통계'] + 10
# Out:
# 0    70
# 1    80
# 2    90
# 3    95
# 4    85
# Name: 통계, dtype: int64

# %%
df['통계'] - 10
# Out:
# 0    50
# 1    60
# 2    70
# 3    75
# 4    65
# Name: 통계, dtype: int64

# %%
df['통계'] * 10
# Out:
# 0    600
# 1    700
# 2    800
# 3    850
# 4    750
# Name: 통계, dtype: int64

# %%
df['통계'] / 10
# Out:
# 0    6.0
# 1    7.0
# 2    8.0
# 3    8.5
# 4    7.5
# Name: 통계, dtype: float64

# %%
df['통계'] % 10
# Out:
# 0    0
# 1    0
# 2    0
# 3    5
# 4    5
# Name: 통계, dtype: int64

# %% [markdown]
# ## 3. 복합 연산

# %%
df = pd.DataFrame({'통계': [60, 70, 80, 85, 75], '미술': [50, 55, 80, 100, 95], '체육': [70, 65, 50, 95, 100] })

# %%
df
# Out:
#    통계   미술   체육
# 0  60   50   70
# 1  70   55   65
# 2  80   80   50
# 3  85  100   95
# 4  75   95  100

# %%
df['통계미술합계'] = df['통계'] + df['미술'] + 10

# %%
df
# Out:
#    통계   미술   체육  통계미술합계
# 0  60   50   70     120
# 1  70   55   65     135
# 2  80   80   50     170
# 3  85  100   95     195
# 4  75   95  100     180

# %%
df['통계'] + df['미술'] - df['체육']
# Out:
# 0     40
# 1     60
# 2    110
# 3     90
# 4     70
# dtype: int64

# %%
df.mean(axis=0)
# Out:
# 통계         74.0
# 미술         76.0
# 체육         76.0
# 통계미술합계    160.0
# dtype: float64

# %% [markdown]
# ## 4. mean(), sum()을 axis 기준으로 연산

# %%
df = pd.DataFrame({'통계': [60, 70, 80, 85, 75], '미술': [50, 55, 80, 100, 95], '체육': [70, 65, 50, 95, 100] })

# %%
df
# Out:
#    통계   미술   체육
# 0  60   50   70
# 1  70   55   65
# 2  80   80   50
# 3  85  100   95
# 4  75   95  100

# %%
df.sum(axis=0)
# Out:
# 통계    370
# 미술    380
# 체육    380
# dtype: int64

# %%
df.mean(axis=0)
# Out:
# 통계    74.0
# 미술    76.0
# 체육    76.0
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# 0    180
# 1    190
# 2    210
# 3    280
# 4    270
# dtype: int64

# %%
df.mean(axis=1)
# Out:
# 0    60.000000
# 1    63.333333
# 2    70.000000
# 3    93.333333
# 4    90.000000
# dtype: float64

# %% [markdown]
# ## 5. NaN 값이 존재할 경우 연산

# %%
df = pd.DataFrame({'통계': [60, 70, np.nan , 85, 75], '미술': [50, np.nan , 80, 100, 95], '체육': [70, 65, 50, np.nan , 100] })

# %%
df
# Out:
#      통계     미술     체육
# 0  60.0   50.0   70.0
# 1  70.0    NaN   65.0
# 2   NaN   80.0   50.0
# 3  85.0  100.0    NaN
# 4  75.0   95.0  100.0

# %%
df['통계'] / 2
# Out:
# 0    30.0
# 1    35.0
# 2     NaN
# 3    42.5
# 4    37.5
# Name: 통계, dtype: float64

# %%
1000 / df['통계']
# Out:
# 0    16.666667
# 1    14.285714
# 2          NaN
# 3    11.764706
# 4    13.333333
# Name: 통계, dtype: float64

# %%
df['통계'] / np.nan
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: 통계, dtype: float64

# %%
np.nan / df['통계']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: 통계, dtype: float64

# %% [markdown]
# ## 6. DataFrame 과 DataFrame 간 연산

# %%
df1 = pd.DataFrame({'통계': [60, 70, 80, 85, 75], '미술': [50, 55, 80, 100, 95], '체육': [70, 65, 50, 95, 100] })

# %%
df2 = pd.DataFrame({'통계': ['good', 'bad', 'ok' , 'good', 'ok'], '미술': [50, 60 , 80, 100, 95], '체육': [70, 65, 50, 70 , 100] })

# %%
df1
# Out:
#    통계   미술   체육
# 0  60   50   70
# 1  70   55   65
# 2  80   80   50
# 3  85  100   95
# 4  75   95  100

# %%
df2
# Out:
#      통계   미술   체육
# 0  good   50   70
# 1   bad   60   65
# 2    ok   80   50
# 3  good  100   70
# 4    ok   95  100

# %% [markdown]
# 문자열이 포함된 DataFrame의 경우

# %%
df1 + df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-fa4784095cc3> in <module>
# ----> 1 df1 + df2
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     649         if isinstance(other, ABCDataFrame):
#     650             # Another DataFrame
# --> 651             new_data = self._combine_frame(other, na_op, fill_value)
#     652
#     653         elif isinstance(other, ABCSeries):
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value)
#    5868                 return func(left, right)
#    5869
# -> 5870         new_data = ops.dispatch_to_series(self, other, _arith_op)
#    5871         return new_data
#    5872
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, axis)
#     273         #  _frame_arith_method_with_reindex
#     274
# --> 275         bm = left._mgr.operate_blockwise(right._mgr, array_op)
#     276         return type(left)(bm)
#     277
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/internals/managers.py in operate_blockwise(self, other, array_op)
#     362         Apply array_op blockwise with another (aligned) BlockManager.
#     363         """
# --> 364         return operate_blockwise(self, other, array_op)
#     365
#     366     def apply(self: T, f, align_keys=None, **kwargs) -> T:
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/internals/ops.py in operate_blockwise(left, right, array_op)
#      36             lvals, rvals = _get_same_shape_values(blk, rblk, left_ea, right_ea)
#      37
# ---> 38             res_values = array_op(lvals, rvals)
#      39             if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      40                 res_values = res_values.reshape(1, -1)
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# 문자열이 포함된 DataFrame의 브로드캐스팅 연산

# %%
df1 + 10
# Out:
#    통계   미술   체육
# 0  70   60   80
# 1  80   65   75
# 2  90   90   60
# 3  95  110  105
# 4  85  105  110

# %%
df2 + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-07ab6372712b> in <module>
# ----> 1 df2 + 10
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     658                 self = self.fillna(fill_value)
#     659
# --> 660             new_data = dispatch_to_series(self, other, op)
#     661
#     662         return self._construct_result(new_data)
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, axis)
#     263     if not is_list_like(right):
#     264         # i.e. scalar, faster than checking np.ndim(right) == 0
# --> 265         bm = left._mgr.apply(array_op, right=right)
#     266         return type(left)(bm)
#     267
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     402
#     403             if callable(f):
# --> 404                 applied = b.apply(f, **kwargs)
#     405             else:
#     406                 applied = getattr(b, f)(**kwargs)
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     344         """
#     345         with np.errstate(all="ignore"):
# --> 346             result = func(self.values, **kwargs)
#     347
#     348         return self._split_op_result(result)
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~/anaconda3/envs/opencv4/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# column의 순서가 바뀌어 있는 경우

# %%
df1 = pd.DataFrame({'미술': [10, 20, 30, 40, 50], '통계':[60, 70, 80, 90, 100] })
df2 = pd.DataFrame({'통계': [10, 20, 30, 40, 50], '미술': [60, 70, 80, 90, 100] })

# %%
df1
# Out:
#    미술   통계
# 0  10   60
# 1  20   70
# 2  30   80
# 3  40   90
# 4  50  100

# %%
df2
# Out:
#    통계   미술
# 0  10   60
# 1  20   70
# 2  30   80
# 3  40   90
# 4  50  100

# %%
df1 + df2
# Out:
#     미술   통계
# 0   70   70
# 1   90   90
# 2  110  110
# 3  130  130
# 4  150  150

# %% [markdown]
# 행의 갯수가 다른경우

# %%
df1 = pd.DataFrame({'미술': [10, 20, 30, 40, 50, 60], '통계':[60, 70, 80, 90, 100, 110] })
df2 = pd.DataFrame({'통계': [10, 20, 30, 40, 50], '미술': [60, 70, 80, 90, 100] })

# %%
df1 * df2
# Out:
#        미술      통계
# 0   600.0   600.0
# 1  1400.0  1400.0
# 2  2400.0  2400.0
# 3  3600.0  3600.0
# 4  5000.0  5000.0
# 5     NaN     NaN
